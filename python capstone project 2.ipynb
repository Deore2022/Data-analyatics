# %%
# Write the program for getting cricket game information 
# Frist we creat the class for cricket
class cricket:
# Now we define the functions.
    def __init__(self):     
        print('****************WELCOME TO THE CRICKET GAME*****************')
# Now we define the function for guessing the toss.
    def toss(self):          
        print('Let TOSS the coin.')
        print('Let guess who win the toss.')
        toss_win_team=int(input('Enter the team number :  '))
        print('1.Team 1')
        print('2.Team 2')
        if (toss_win_team==1):
            print(' Team 1 win the toss and choose BALL first')
        else:
            print('Team 2 win the toss and choose BAT first')
# Now we define the function for inning of the match.
    def Innings(self):               
        print('~~~~~~~~~~~~~~~~~~~~~~~~~~~LET START THE MATCH~~~~~~~~~~~~~~~~~~~~~~~~~')
        first_inning_runs=int(input('Enter the runs done by first team :  '))   # Here we enter the first inning runs done by the team who bat first.
        second_inning_runs=int(input('Enter the runs done by second team : '))  # Here we enter the second inning runs done by the team who bat second.
        if (first_inning_runs>second_inning_runs):
            print('The team first is win the match.')
        elif(first_inning_runs<second_inning_runs):
            print('The team second is win the match')
        else:
            print('The match is get tie.')
# Now we define the function for wickets.
    def Wickets(self):
        first_team_wickets=int(input('Enter the first team wickets : '))
        second_team_wickets=int(input('Enter the second team wickets : '))
        if (first_team_wickets>second_team_wickets):
            print('The first team BALLER are good today.')
        elif (first_team_wickets<second_team_wickets):
            print('The second team BALLER are good today.')
        else:
            print('The BALLERS are oky today.')
# Now we define the function from this match who are the man of the match.
    def Best_batsmen_of_the_match(self):
        print('~~~~~~~~~~~~Let select the Best batsmen of todays match.~~~~~~~~~~~')
        runs=int(input('Enter the runs done by the batsmen :  '))
        if (runs>75):
            print('The BATSMEN is best today.')
        else:
            print('The BATSMEN is not best today.')
    def Best_baller_of_the_match(self):
        print('**********Let select the Best baller of todays match.**********')
        wickets=int(input('Enter the wickets taken by the baller :  '))
        if (wickets>4):
            print('The Baller is best today.')
        else:
            print('The Baller is not best today.')

x=cricket()
x.toss()
x.Innings()
x.Wickets()
x.Best_batsmen_of_the_match()
x.Best_baller_of_the_match()


print('THANK YOU! FOR WATCHING THE MATCH.')
print('WE MEET AGAIN IN NEXT MATCH.')
